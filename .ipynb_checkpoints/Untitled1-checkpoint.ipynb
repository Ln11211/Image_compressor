# %%
import tensorflow as tf
import keras
import PIL.Image as img
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist = tf.keras.datasets.cifar10
(training_images,_), (val_images,_) = mnist.load_data()
training_images=training_images/ 255.0
val_images=val_images/ 255.0

# %%
print(np.shape(training_images[1]))
print(type(training_images[1]))
plt.figure(figsize=(1,1))
plt.imshow(training_images[1])
# Out:
# (32, 32, 3)
# <class 'numpy.ndarray'>

# %%
training_images=training_images.reshape(len(training_images),32,32,3)
val_images=val_images.reshape(len(val_images),32,32,3)

# %%
model=None
model=keras.models.Sequential([
    keras.layers.Conv2D(32,(3,3),padding='same',activation='relu',input_shape=(32,32,3),name='first'),
    keras.layers.MaxPooling2D(2,padding='same'),

    keras.layers.Conv2D(16,(3,3),padding='same',activation='relu',name='second'),
    keras.layers.MaxPooling2D(2,padding='same'),
    
    keras.layers.Flatten(),
    keras.layers.Reshape((1,-1),name='rs1'),
    
    keras.layers.LSTM(1024,name='lstm1'),
    keras.layers.Reshape((1,-1),name='rs2'),
    keras.layers.LSTM(1024,name='lstm2'),
    keras.layers.Reshape((1,-1),name='rs3'),
    keras.layers.LSTM(1024,name='lstm3'),
    
    keras.layers.Reshape((8,8,16),name='rs4'),
    
    #decoder network
    keras.layers.Conv2D(16,(3,3),activation='relu',padding='same',name='third'),
    keras.layers.UpSampling2D(2),
    
    keras.layers.Conv2D(32,(3,3),activation='relu',padding='same',name='fourth'),
    keras.layers.UpSampling2D(2),
    
    keras.layers.Conv2D(3,(3,3),activation='sigmoid',padding='same',name='last')
])

# %%
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),loss='binary_crossentropy')
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  first (Conv2D)              (None, 32, 32, 32)        896
#
#  max_pooling2d_84 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  second (Conv2D)             (None, 16, 16, 16)        4624
#
#  max_pooling2d_85 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  flatten_34 (Flatten)        (None, 1024)              0
#
#  rs1 (Reshape)               (None, 1, 1024)           0
#
#  lstm1 (LSTM)                (None, 1024)              8392704
#
#  rs2 (Reshape)               (None, 1, 1024)           0
#
#  lstm2 (LSTM)                (None, 1024)              8392704
#
#  rs3 (Reshape)               (None, 1, 1024)           0
#
#  lstm3 (LSTM)                (None, 1024)              8392704
#
#  rs4 (Reshape)               (None, 8, 8, 16)          0
#
#  third (Conv2D)              (None, 8, 8, 16)          2320
#
# ...

# %%
history=model.fit(training_images,training_images,epochs=10,batch_size=256,validation_data=(val_images,val_images))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 235s 1s/step - loss: 0.6210 - val_loss: 0.5948
# Epoch 2/10
# 196/196 [==============================] - 211s 1s/step - loss: 0.5850 - val_loss: 0.5802
# Epoch 3/10
# 196/196 [==============================] - 202s 1s/step - loss: 0.5765 - val_loss: 0.5752
# Epoch 4/10
# 196/196 [==============================] - 198s 1s/step - loss: 0.5729 - val_loss: 0.5729
# Epoch 5/10
# 196/196 [==============================] - 203s 1s/step - loss: 0.5703 - val_loss: 0.5821
# Epoch 6/10
# 196/196 [==============================] - 208s 1s/step - loss: 0.5700 - val_loss: 0.5687
# Epoch 7/10
# 196/196 [==============================] - 190s 969ms/step - loss: 0.5670 - val_loss: 0.5680
# Epoch 8/10
#  14/196 [=>............................] - ETA: 2:58 - loss: 0.5687
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
pred=model.predict(val_images)
# Out:
# 313/313 [==============================] - 4s 12ms/step

# %%
plt.subplot(1,2,1)
plt.imshow(val_images[1])
plt.title("original")
plt.subplot(1,2,2)
plt.imshow(pred[1])
plt.title("reconstructed")
# Out:
# Text(0.5, 1.0, 'reconstructed')

# %%
plt.subplot(1,2,1)
plt.imshow(val_images[1])
plt.title("original")
plt.subplot(1,2,2)
plt.imshow(pred[1])
plt.title("reconstructed")
# Out:
# Text(0.5, 1.0, 'reconstructed')

# %%
original=(val_images[1]*255)
recons=(pred[1]*255)

original=np.squeeze(original).astype(np.uint8)
recons=np.squeeze(recons).astype(np.uint8)

# %%
original=img.fromarray(original)
recons=img.fromarray(recons)

# %%
import os
os.mkdir(os.path.join(os.getcwd(),'results_vae'))

# %%
os.chdir(os.path.join(os.getcwd(),'results_vae'))

# %%
original.save('original.jpg')
recons.save('recons.jpg')

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from PIL import Image as img
# %matplotlib inline

# %%
cat_pic=img.open("cat_Ashleyn.jpg")  #load up a custom image

# %%
print(np.shape(cat_pic))
cat_pic
# Out:
# (895, 592, 3)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=592x895>

# %%
def compressor(image,n_clusters,size):
    image=image.resize(size)
    rows=np.shape(image)[0]
    cols=np.shape(image)[1]
    
    image=np.array(image)
    image=image.reshape(rows*cols,3)
    
    km=KMeans(n_clusters=64)
    km.fit(image)
    
    cmprs_img = km.cluster_centers_[km.labels_]
    cmprs_img = np.clip(cmprs_img.astype('uint8'), 0, 255)
    cmprs_img = np.array(cmprs_img.reshape(rows, cols, 3))
    cmprs_img=img.fromarray(cmprs_img)
    
    return cmprs_img

# %%
comp_2=compressor(cat_pic,2,(600,900)) #2 clusters only in the final image
comp_8=compressor(cat_pic,8,(600,900)) #8 clusters only in the final image
comp_16=compressor(cat_pic,16,(600,900)) #16 clusters
comp_64=compressor(cat_pic,64,(600,900)) #64 clusters

# %%
images=[comp_2,comp_8,comp_16,comp_64]
imgs=["comp_2","comp_8","comp_16","comp_64"]
plt.axis('off')
plt.figure(figsize=(12,18))
plt.subplot(3,2,1)
plt.imshow(cat_pic)
plt.title("Original")

for i,image in enumerate(images):
    plt.subplot(3,2,i+2)
    plt.imshow(image)
    plt.title(imgs[i])

# %%
bird=img.open('scarlet_tanager_greg_lavaty_300.jpg')
print(np.shape(bird))
bird
# Out:
# (285, 285, 3)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=285x285>

# %%
comp_2=compressor(bird,2,(300,300)) #2 clusters only in the final image
comp_8=compressor(bird,8,(300,300)) #8 clusters only in the final image
comp_16=compressor(bird,16,(300,300)) #16 clusters
comp_64=compressor(bird,64,(300,300)) #64 clusters

# %%
images=[comp_2,comp_8,comp_16,comp_64]
imgs=["comp_2","comp_8","comp_16","comp_64"]
plt.axis('off')
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.imshow(bird)
plt.title("Original")

for i,image in enumerate(images):
    plt.subplot(3,2,i+2)
    plt.imshow(image)
    plt.title(imgs[i])

# %%
import os
os.mkdir(os.path.join(os.getcwd(),'results'))
os.chdir('results')

# %%
images=[bird,comp_2,comp_8,comp_16,comp_64]
imgs=["original","comp_2","comp_8","comp_16","comp_64"]
for i,image in enumerate(images):
    image.save(imgs[i]+'.jpg')
